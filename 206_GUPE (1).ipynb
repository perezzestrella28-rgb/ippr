# %%
print("operadores matematicos")
print("raliza la suma 4 + 4 =" , 4 + 4)
print("realiza la resta 8 - 6 =" , 8 - 6)
# Out:
# operadores matematicos
# raliza la suma 4 + 4 = 8
# realiza la resta 8 - 6 = 2

# %%
print("realiza la multiplicacion 5 * 4 =" , 5 * 4)
# Out:
# realiza la multiplicacion 5 * 4 = 20

# %%
print("realiza la multiplicacion 4 * 2 =" , 4 * 2)
# Out:
# realiza la multiplicacion 4 * 2 = 8

# %%
print("realiza la multiplicacion 2 * 3 =" , 2 * 3)
# Out:
# realiza la multiplicacion 2 * 3 = 6

# %%
print("realiza la multiplicacion 3 * 3 =" , 3 * 3)
# Out:
# realiza la multiplicacion 3 * 3 = 9

# %%
print("realiza la multiplicacio 5 * 2 =" , 5 * 2)
# Out:
# realiza la multiplicacio 5 * 2 = 10

# %%
print("realiza la multiplicacion 8 * 6 =" , 8 * 6)
# Out:
# realiza la multiplicacion 8 * 6 = 48

# %%
print("realiza la multiplicacion 9 * 9 =" , 9 * 9)
# Out:
# realiza la multiplicacion 9 * 9 = 81

# %%
print("realiza la multiplicacion 7 * 2 =" , 7 * 2)
# Out:
# realiza la multiplicacion 7 * 2 = 14

# %%
print("realiza la multiplicacion 7 * 7 =" , 7 * 7)
# Out:
# realiza la multiplicacion 7 * 7 = 49

# %%
print("realiza la multiplicacion 10 * 3 =" , 10 * 3)
# Out:
# realiza la multiplicacion 10 * 3 = 30

# %%
print("realiza la suma 6 + 4 =" , 6 + 4)
# Out:
# realiza la suma 6 + 4 = 10

# %%
print("realiza la suma 9 + 11 =" , 9 + 11)
# Out:
# realiza la suma 9 + 11 = 20

# %%
print("realiza la suma 11 + 20 =" , 11 + 20)
# Out:
# realiza la suma 11 + 20 = 31

# %%
print("realiza la suma 2 + 9 =" , 2 + 9)
# Out:
# realiza la suma 2 + 9 = 11

# %%
print("realiza la suma 30 + 5 =" , 30 + 5)
# Out:
# realiza la suma 30 + 5 = 35

# %%
print("realiza la suma 13 + 4 =" , 13 + 4)
# Out:
# realiza la suma 13 + 4 = 17

# %%
print("realiza la suma 5 + 19 =" , 5 + 19)
# Out:
# realiza la suma 5 + 19 = 24

# %%
print("realiza la suma 88 + 9 =" , 88 + 9)
# Out:
# realiza la suma 88 + 9 = 97

# %%
print("realiza la suma 7 + 8 =" , 7 + 8)
# Out:
# realiza la suma 7 + 8 = 15

# %%
print("realiza la suma 30 + 30 =" , 30 + 30)
# Out:
# realiza la suma 30 + 30 = 60

# %%
print("realiza la resta 4 - 2 =" , 4 - 2)
# Out:
# realiza la resta 4 - 2 = 2

# %%
print("realiza la resta 6 - 3 =" , 6 - 3)
# Out:
# realiza la resta 6 - 3 = 3

# %%
print("realiza la resta 100 - 50 =" , 100 - 50)
# Out:
# realiza la resta 100 - 50 = 50

# %%
print("realiza la resta 10 - 10 =" , 10 - 10)
# Out:
# realiza la resta 10 - 10 = 0

# %%
print("realiza la resta 5 - 3 =" , 5 - 3)
# Out:
# realiza la resta 5 - 3 = 2

# %%
print("realiza la resta 8 - 4 =" , 8 - 4)
# Out:
# realiza la resta 8 - 4 = 4

# %%
print("realiza la resta 38 - 26 =" , 38 - 26)
# Out:
# realiza la resta 38 - 26 = 12

# %%
print("realiza la resta 9 - 4 =" , 9 - 4)
# Out:
# realiza la resta 9 - 4 = 5

# %%
print("realiza la resta 76 - 8 =" , 76 - 8)
# Out:
# realiza la resta 76 - 8 = 68

# %%
print("realiza la resta 33 - 4 =" , 33 - 4)
# Out:
# realiza la resta 33 - 4 = 29

# %%
print("realiza la division 20 / 2 =" , 20 / 2)
# Out:
# realiza la division 20 / 2 = 10.0

# %%
print("realiza la division 50 / 4 =" , 50 / 4)
# Out:
# realiza la division 50 / 4 = 12.5

# %%
print("realiza la division 10 / 2 =" , 10 / 2)
# Out:
# realiza la division 10 / 2 = 5.0

# %%
print("realiza la division 70 / 4 =" , 70 / 4)
# Out:
# realiza la division 70 / 4 = 17.5

# %%
print("reliza la division 80 / 4 =" , 80 / 4)
# Out:
# reliza la division 80 / 4 = 20.0

# %%
print("realiza la division 65 / 4 =" , 65 / 4)
# Out:
# realiza la division 65 / 4 = 16.25

# %%
print("realiza la division 60 / 8 =" , 60 / 8)
# Out:
# realiza la division 60 / 8 = 7.5

# %%
print("realiza la division 88 / 5 =" , 88 / 5)
# Out:
# realiza la division 88 / 5 = 17.6

# %%
print("realiza la division 77 / 4 =" , 77 / 4)
# Out:
# realiza la division 77 / 4 = 19.25

# %%
print("realiza la divivision 100 / 2 =" , 100 / 2)
# Out:
# realiza la divivision 100 / 2 = 50.0
