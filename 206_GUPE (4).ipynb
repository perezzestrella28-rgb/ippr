# %%
# Programa para calcular el promedio de 5 calificaciones
#guillen estrella

# Lista con 5 calificaciones inventadas
calificaciones = [8.5, 9.0, 7.5, 10.0, 8.0]

# Sumar todas las calificaciones
suma = sum(calificaciones)

# Calcular el promedio
promedio = suma / len(calificaciones)

# Mostrar resultados
print("Calificaciones:")
for calificacion in calificaciones:
    print(calificacion)

print("\nPromedio:", promedio)
# Out:
# Calificaciones:
# 8.5
# 9
# 7
# 10
# 8
#
# Promedio: 8.5

# %%
#sorteo
#Guillen Estrella

original = {45, 12, 78, 3, 56}
nueva = sorted(original)
desc = sorted(original, reverse=True)
import random

original = {45, 12, 78, 3, 56}

# Convertimos el conjunto a lista para poder elegir
lista = list(original)

# Sorteo: elegir un ganador al azar
ganador = random.choice(lista)

print("Participantes:", lista)
print("El ganador es:", ganador)
# Out:
# Participantes: [3, 56, 12, 45, 78]
# El ganador es: 56
