# %%
"mexico" # texto
45 #numerico
3.1416 #floattrue
#logico

==

# %%
a = 4
b = 9
if type(b) is not int:
  raise exception ("el valor de b debe ser un numero entero")

elif b
# Out:
#   File "/tmp/ipykernel_1409/959354626.py", line 6
#     elif b
#            ^
# SyntaxError: expected ':'

# %%
a = 50
b = 50
if a < b:
  print(a, "es menor que", b)
elif a > b:
  print(a, "es mayor que", b)
else:
  print(a, "es igual que", b)
# Out:
# 50 es igual que 50

# %%
a = int(input("enter the firs number: "))
b =(input("enter the second number: "))

# %%
for i in (8, 5)
 if i % 2 == 0
 print(i, "es par")
 else
